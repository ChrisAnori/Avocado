# %%
# Punto 2.1

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose   # para descomponer la serie temporal de precios en componentes de tendencia, estacionalidad y ruido.

# Cargar el conjunto de datos
data = pd.read_csv('/home/jose/avocado/Avocado/regresion/avocado.csv')
data_avo=data.copy() 

regiones_geograficas= ["California","GreatLakes","Midsouth","Northeast","Plains","SouthCentral","Southeast","West"]
data_avo=data_avo[data_avo['region'].isin(regiones_geograficas)]
data_avo['Date'] = pd.to_datetime(data_avo['Date'])

# Crear el gráfico de violín usando seaborn
plt.figure(figsize=(12, 8))
sns.violinplot(x='region', y='Total Volume', data=data_avo,palette='coolwarm')  # ,inner='quartile'

# Configurar etiquetas y títulos
plt.title('Distribución del Volumen Total de Ventas de Aguacates por Región')
plt.xlabel('Región')
plt.ylabel('Volumen Total de Ventas')

# Rotar las etiquetas del eje x para facilitar la lectura si hay muchas regiones
plt.xticks(rotation=90)

# Mostrar el gráfico
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_84650/3305451885.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='region', y='Total Volume', data=data_avo,palette='coolwarm')  # ,inner='quartile'

# %%
# Punto 2.2
# Configurar el tamaño del gráfico
plt.figure(figsize=(10, 6))
(np.min(AveragePrice))
 
# Crear el boxplot comparativo de precios entre años
sns.boxplot(x='year', y='AveragePrice', data=data_avo)
    
# Añadir título y etiquetas de ejes
plt.title('Distribución Comparativa de Precios de Aguacates por Año')
plt.xlabel('Año')
plt.ylabel('Precio Promedio')
    
# Mostrar el gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       1 # Punto 2.2
#       2 # Configurar el tamaño del gráfico
#       3 plt.figure(figsize=(10, 6))
# ----> 4 (np.min(AveragePrice))
#       6 # Crear el boxplot comparativo de precios entre años
#       7 sns.boxplot(x='year', y='AveragePrice', data=data_avo)
#
# NameError: name 'np' is not defined

# %%
#punto 2.3 

# Crear el histograma
plt.figure(figsize=(10, 6))
plt.hist(data_avo['Total Volume'], bins=10, color='green', edgecolor='black',range=(20000, 35000))

# Añadir etiquetas y título
plt.title('Distribución del Volumen Total de Ventas de Aguacates')
plt.xlabel('Volumen Total de Ventas')
plt.ylabel('Frecuencia')

# Mostrar el gráfico
plt.grid(axis='y', alpha=0.75)
plt.show()
